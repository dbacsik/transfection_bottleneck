# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Analyze-viral-barcodes-from-barcode-specific-Illumina-sequencing" data-toc-modified-id="Analyze-viral-barcodes-from-barcode-specific-Illumina-sequencing-1">Analyze viral barcodes from barcode-specific Illumina sequencing</a></span><ul class="toc-item"><li><span><a href="#Setup-for-analysis" data-toc-modified-id="Setup-for-analysis-1.1">Setup for analysis</a></span><ul class="toc-item"><li><span><a href="#Parameters" data-toc-modified-id="Parameters-1.1.1">Parameters</a></span></li><li><span><a href="#Import-Python-modules" data-toc-modified-id="Import-Python-modules-1.1.2">Import Python modules</a></span></li><li><span><a href="#Temporary-way-to-read-in-parameters" data-toc-modified-id="Temporary-way-to-read-in-parameters-1.1.3">Temporary way to read in parameters</a></span></li></ul></li><li><span><a href="#Parse-the-viral-barcodes" data-toc-modified-id="Parse-the-viral-barcodes-1.2">Parse the viral barcodes</a></span></li><li><span><a href="#Examine-&quot;fates&quot;-of-barcode-reads" data-toc-modified-id="Examine-&quot;fates&quot;-of-barcode-reads-1.3">Examine "fates" of barcode reads</a></span></li><li><span><a href="#Examine-distribution-of-barcodes" data-toc-modified-id="Examine-distribution-of-barcodes-1.4">Examine distribution of barcodes</a></span></li><li><span><a href="#Rarefaction-curves-for-barcodes" data-toc-modified-id="Rarefaction-curves-for-barcodes-1.5">Rarefaction curves for barcodes</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Analyze viral barcodes from barcode-specific Illumina sequencing
# This Python Jupyter notebook process Illumina sequencing of just the viral barcodes that have been amplified by specific PCR of that region.
#
# # Goal
# The goal of this notebook is to compare a variety of rescue conditions. We'd like to learn something about the best practices for rescuing, with the most largest bottleneck.

# %% [markdown]
# ## Setup for analysis
#
# ### Parameters
# The next cell is tagged as a `parameters` cell.
# That means that when you run with [papermill parameterization](https://papermill.readthedocs.io/en/latest/usage.html#parameterizing-a-notebook), there will be a cell inserted immediately after it with the actual parameterized values for these inputs parameters.
#
# The cell must specify:
#  - `sample_csv`: CSV file that lists *sample*, *gene*, *datafile* (location of R1 FASTQ files), and *datatype*. We only consider rows of *datatype* equal to *viral_barcode_fastqs*.
#  - `barcodelength`: length of the viral barcodes.
#  - `upstream`: dict keyed by each gene, with values being the upstream sequence
#  - `downstream`: dict keyed by each gene, with values being the downstream sequence
#  - `upstream_mismatch`: allowed mismatches upstream
#  - `downstream_mismatch`: allowed mismatched downstream
#  - `viral_barcode_counts`: created CSV file in tidy format where columns are *sample*, *viral_barcode*, *count*
#
# For now, the cell is just empty as the values will be set by `papermill`.

# %%
# Parameters cell

# %% [markdown]
# ### Import Python modules
# Use [dms_tools2](https://jbloomlab.github.io/dms_tools2/) for barcode parsing and [plotnine](https://plotnine.readthedocs.io) for ggplot2-like plotting:

# %%
import glob
import os
import yaml
import pandas as pd
from IPython.display import display, HTML
from plotnine import *
import dms_tools2

# %% [markdown]
# ### Temporary way to read in parameters
# For now, just read parameters from `config.yaml` since we aren't yet parameterizing notebook:

# %%
with open('config.yaml') as f:
    config = yaml.load(f)
    
upstream = config['viral_barcode_upstream']
downstream = config['viral_barcode_downstream']
upstream_mismatch = config['viral_barcode_upstream_mismatch']
downstream_mismatch = config['viral_barcode_downstream_mismatch']
barcodelength = config['viral_barcode_length']

sample_csv = 'sampledata.csv'
metadata_csv = 'metadata.csv'

results_dir = 'results'
if not os.path.exists(results_dir):
    os.makedirs(results_dir)

# %% [markdown]
# ## Parse the viral barcodes
# The viral barcodes and their data locations are specified in *sample_csv*. Here, we read them in.

# %%
samples = pd.read_csv(sample_csv,comment="#").query('datatype == "viral_barcode_fastqs"')

pd.set_option('max.colwidth', -1)
display(HTML(samples.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>sample</th>
#       <th>datatype</th>
#       <th>gene</th>
#       <th>datafile</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>fluHA_virus_transfection_1</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>/shared/ngs/illumina/bloom_lab/190507_M03100_0428_000000000-CG8CT/Data/Intensities/BaseCalls/bcHA-virus-transfection-sample1_S5_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>fluHA_virus_transfection_2</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>/shared/ngs/illumina/bloom_lab/190507_M03100_0428_000000000-CG8CT/Data/Intensities/BaseCalls/bcHA-virus-transfection-sample2_S6_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>fluHA_virus_passaged_1</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>/shared/ngs/illumina/bloom_lab/190507_M03100_0428_000000000-CG8CT/Data/Intensities/BaseCalls/bcHA-virus-passaged-sample1_S7_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>fluHA_virus_passaged_2</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>/shared/ngs/illumina/bloom_lab/190507_M03100_0428_000000000-CG8CT/Data/Intensities/BaseCalls/bcHA-virus-passaged-sample2_S8_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-Mike-cc</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-monster-Mike-cc_S10_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-monster-Mike-cc_S10_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-Mike-OL</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-monster-Mike-OL_S11_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-monster-Mike-OL_S11_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-pCAWS-cc</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-monster-pCAWS-cc_S12_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-monster-pCAWS-cc_S12_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-pCAWS-OL</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-monster-pCAWS-OL_S13_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-monster-pCAWS-OL_S13_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-pHW-cc-2ug</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-pHW-cc-2ug_S14_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-pHW-cc-2ug_S14_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-pHW-cc-4ug</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-pHW-cc-4ug_S15_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-pHW-cc-4ug_S15_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>WTBC-405-pdm-seq</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/WTBC-405-pdm-seq_S16_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-WTBC-405-pdm-seq_S16_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>WTBC-405-wsn-seq</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/WTBC-405-wsn-seq_S17_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-WTBC-405-wsn-seq_S17_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>WTBC-33-wsn-seq</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/WTBC-33-wsn-seq_S18_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-WTBC-33-wsn-seq_S18_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>WTBC-405-pdm-OL</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/WTBC-405-pdm-OL_S19_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-WTBC-405-pdm-OL_S19_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>WTBC-405-wsn-OL</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/WTBC-405-wsn-OL_S20_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-WTBC-405-wsn-OL_S20_L001_R1_001.fastq.gz</td>
#     </tr>
#     <tr>
#       <td>WTBC-33-wsn-OL</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/WTBC-33-wsn-OL_S21_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-WTBC-33-wsn-OL_S21_L001_R1_001.fastq.gz</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Read all the barcodes into a data frame using the [dms_tools2.barcodes.IlluminaBarcodeParser](https://jbloomlab.github.io/dms_tools2/dms_tools2.barcodes.html#dms_tools2.barcodes.IlluminaBarcodeParser):

# %%
barcodes_file = results_dir + '/' + 'barcodes.csv'
fates_file = results_dir + '/' + 'fates.csv'

if os.path.exists(barcodes_file) and os.path.exists(fates_file):
    barcodes = pd.read_csv(barcodes_file)
    fates = pd.read_csv(fates_file)
else:
    barcodes = []
    fates = []

    for tup in samples.itertuples(index=False):

        parser = dms_tools2.barcodes.IlluminaBarcodeParser(
                    bclen=barcodelength,
                    upstream=upstream[tup.gene],
                    downstream=downstream[tup.gene],
                    upstream_mismatch=upstream_mismatch,
                    downstream_mismatch=downstream_mismatch)

        if '.fastq.gz' in tup.datafile:
            r1files = tup.datafile.split(',')
        else:
            r1files = glob.glob(os.path.join(tup.datafile, '*R1*.fastq.gz'))

        assert len(r1files)

        print(f"\nReading viral barcodes for {tup.sample} from {len(r1files)} R1 files")
        print("The files are:")
        print(*r1files, sep = "\n")

        ibarcodes, ifates = parser.parse(r1files)

        barcodes.append(ibarcodes.assign(sample=tup.sample))
        fates.append(ifates.assign(sample=tup.sample))

    barcodes = pd.concat(barcodes)
    fates = pd.concat(fates)


    print(f'Writing barcodes to {barcodes_file}')
    barcodes.to_csv(barcodes_file)

    print(f'Writing barcodes to {fates_file}')
    fates.to_csv(fates_file)
# Out:
# Reading viral barcodes for fluHA_virus_transfection_1 from 1 R1 files
# The files are:
# /shared/ngs/illumina/bloom_lab/190507_M03100_0428_000000000-CG8CT/Data/Intensities/BaseCalls/bcHA-virus-transfection-sample1_S5_L001_R1_001.fastq.gz
#
# Reading viral barcodes for fluHA_virus_transfection_2 from 1 R1 files
# The files are:
# /shared/ngs/illumina/bloom_lab/190507_M03100_0428_000000000-CG8CT/Data/Intensities/BaseCalls/bcHA-virus-transfection-sample2_S6_L001_R1_001.fastq.gz
#
# Reading viral barcodes for fluHA_virus_passaged_1 from 1 R1 files
# The files are:
# /shared/ngs/illumina/bloom_lab/190507_M03100_0428_000000000-CG8CT/Data/Intensities/BaseCalls/bcHA-virus-passaged-sample1_S7_L001_R1_001.fastq.gz
#
# Reading viral barcodes for fluHA_virus_passaged_2 from 1 R1 files
# The files are:
# /shared/ngs/illumina/bloom_lab/190507_M03100_0428_000000000-CG8CT/Data/Intensities/BaseCalls/bcHA-virus-passaged-sample2_S8_L001_R1_001.fastq.gz
#
# Reading viral barcodes for m-WTBC-monster-Mike-cc from 2 R1 files
# The files are:
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-monster-Mike-cc_S10_L001_R1_001.fastq.gz
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-monster-Mike-cc_S10_L001_R1_001.fastq.gz
#
# Reading viral barcodes for m-WTBC-monster-Mike-OL from 2 R1 files
# The files are:
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-monster-Mike-OL_S11_L001_R1_001.fastq.gz
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-monster-Mike-OL_S11_L001_R1_001.fastq.gz
#
# Reading viral barcodes for m-WTBC-monster-pCAWS-cc from 2 R1 files
# The files are:
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-monster-pCAWS-cc_S12_L001_R1_001.fastq.gz
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-monster-pCAWS-cc_S12_L001_R1_001.fastq.gz
#
# Reading viral barcodes for m-WTBC-monster-pCAWS-OL from 2 R1 files
# The files are:
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-monster-pCAWS-OL_S13_L001_R1_001.fastq.gz
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-monster-pCAWS-OL_S13_L001_R1_001.fastq.gz
#
# Reading viral barcodes for m-WTBC-pHW-cc-2ug from 2 R1 files
# The files are:
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-pHW-cc-2ug_S14_L001_R1_001.fastq.gz
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-pHW-cc-2ug_S14_L001_R1_001.fastq.gz
#
# Reading viral barcodes for m-WTBC-pHW-cc-4ug from 2 R1 files
# The files are:
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-pHW-cc-4ug_S15_L001_R1_001.fastq.gz
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-pHW-cc-4ug_S15_L001_R1_001.fastq.gz
#
# Reading viral barcodes for WTBC-405-pdm-seq from 2 R1 files
# The files are:
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/WTBC-405-pdm-seq_S16_L001_R1_001.fastq.gz
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-WTBC-405-pdm-seq_S16_L001_R1_001.fastq.gz
#
# Reading viral barcodes for WTBC-405-wsn-seq from 2 R1 files
# The files are:
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/WTBC-405-wsn-seq_S17_L001_R1_001.fastq.gz
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-WTBC-405-wsn-seq_S17_L001_R1_001.fastq.gz
#
# Reading viral barcodes for WTBC-33-wsn-seq from 2 R1 files
# The files are:
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/WTBC-33-wsn-seq_S18_L001_R1_001.fastq.gz
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-WTBC-33-wsn-seq_S18_L001_R1_001.fastq.gz
#
# Reading viral barcodes for WTBC-405-pdm-OL from 2 R1 files
# The files are:
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/WTBC-405-pdm-OL_S19_L001_R1_001.fastq.gz
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-WTBC-405-pdm-OL_S19_L001_R1_001.fastq.gz
#
# Reading viral barcodes for WTBC-405-wsn-OL from 2 R1 files
# The files are:
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/WTBC-405-wsn-OL_S20_L001_R1_001.fastq.gz
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-WTBC-405-wsn-OL_S20_L001_R1_001.fastq.gz
#
# Reading viral barcodes for WTBC-33-wsn-OL from 2 R1 files
# The files are:
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/WTBC-33-wsn-OL_S21_L001_R1_001.fastq.gz
# /fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-WTBC-33-wsn-OL_S21_L001_R1_001.fastq.gz
# Writing barcodes to results/barcodes.csv
# Writing barcodes to results/fates.csv

# %% [markdown]
# ## Examine "fates" of barcode reads
# We look at how many of the barcode reads we could parse:

# %%
p = (
    ggplot(fates, aes('sample', 'count', fill='fate')) +
    geom_bar(stat='identity', position="stack") +
    ylab('number of reads') +
    theme(axis_text_x=element_text(angle=90),
          figure_size=(1 + len(fates['sample'].unique()), 2)) 
    )
_ = p.draw()

# %%
fates
# Out:
#                   fate    count                      sample
# 0  valid barcode        2725406  fluHA_virus_transfection_1
# 1  low quality barcode  245822   fluHA_virus_transfection_1
# 2  unparseable barcode  215111   fluHA_virus_transfection_1
# 0  valid barcode        2228610  fluHA_virus_transfection_2
# 1  low quality barcode  216755   fluHA_virus_transfection_2
# 2  unparseable barcode  175690   fluHA_virus_transfection_2
# 0  valid barcode        2051889  fluHA_virus_passaged_1
# 1  low quality barcode  181161   fluHA_virus_passaged_1
# 2  unparseable barcode  174560   fluHA_virus_passaged_1
# 0  valid barcode        2504792  fluHA_virus_passaged_2
# 1  low quality barcode  238627   fluHA_virus_passaged_2
# 2  unparseable barcode  229208   fluHA_virus_passaged_2
# 0  valid barcode        672146   m-WTBC-monster-Mike-cc
# 1  low quality barcode  100304   m-WTBC-monster-Mike-cc
# 2  unparseable barcode  43166    m-WTBC-monster-Mike-cc
# 0  valid barcode        655110   m-WTBC-monster-Mike-OL
# 1  low quality barcode  98259    m-WTBC-monster-Mike-OL
# 2  unparseable barcode  36732    m-WTBC-monster-Mike-OL
# 0  valid barcode        591893   m-WTBC-monster-pCAWS-cc
# 1  low quality barcode  88447    m-WTBC-monster-pCAWS-cc
# 2  unparseable barcode  33451    m-WTBC-monster-pCAWS-cc
# 0  valid barcode        783240   m-WTBC-monster-pCAWS-OL
# 1  low quality barcode  117098   m-WTBC-monster-pCAWS-OL
# 2  unparseable barcode  38319    m-WTBC-monster-pCAWS-OL
# 0  valid barcode        714278   m-WTBC-pHW-cc-2ug
# 1  low quality barcode  107474   m-WTBC-pHW-cc-2ug
# 2  unparseable barcode  37403    m-WTBC-pHW-cc-2ug
# 0  valid barcode        642044   m-WTBC-pHW-cc-4ug
# 1  low quality barcode  96355    m-WTBC-pHW-cc-4ug
# 2  unparseable barcode  35522    m-WTBC-pHW-cc-4ug
# 0  valid barcode        630395   WTBC-405-pdm-seq
# 1  low quality barcode  102138   WTBC-405-pdm-seq
# 2  unparseable barcode  34980    WTBC-405-pdm-seq
# 0  valid barcode        705290   WTBC-405-wsn-seq
# 1  low quality barcode  105682   WTBC-405-wsn-seq
# 2  unparseable barcode  38078    WTBC-405-wsn-seq
# 0  valid barcode        715360   WTBC-33-wsn-seq
# 1  low quality barcode  107216   WTBC-33-wsn-seq
# 2  unparseable barcode  41811    WTBC-33-wsn-seq
# 0  valid barcode        740424   WTBC-405-pdm-OL
# 1  low quality barcode  111392   WTBC-405-pdm-OL
# 2  unparseable barcode  42815    WTBC-405-pdm-OL
# 0  valid barcode        644948   WTBC-405-wsn-OL
# 1  low quality barcode  96688    WTBC-405-wsn-OL
# 2  unparseable barcode  36813    WTBC-405-wsn-OL
# 0  valid barcode        611234   WTBC-33-wsn-OL
# 1  low quality barcode  91377    WTBC-33-wsn-OL
# 2  unparseable barcode  36070    WTBC-33-wsn-OL

# %% [markdown]
# ### Load metadata
# Want to load in information about how the experiments were prepared.  I'll load this from the separate metadata file,  calculate a few parameters, and join this onto the sample dataframe.

# %%
metadata = pd.read_csv(metadata_csv,comment="#")

pd.set_option('max.colwidth', -1)
display(HTML(metadata.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>sample</th>
#       <th>experiment</th>
#       <th>timepoint</th>
#       <th>cells</th>
#       <th>fluNA</th>
#       <th>fluHA</th>
#       <th>fluInt</th>
#       <th>vRNP</th>
#       <th>dna</th>
#       <th>helper</th>
#       <th>titer_uL</th>
#       <th>uL_sup</th>
#       <th>concentrated</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>fluHA_virus_transfection_1</td>
#       <td>db_large</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>102ug</td>
#       <td>none</td>
#       <td>48063.809</td>
#       <td>500</td>
#       <td>none</td>
#     </tr>
#     <tr>
#       <td>fluHA_virus_transfection_2</td>
#       <td>db_large</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>102ug</td>
#       <td>none</td>
#       <td>48063.809</td>
#       <td>500</td>
#       <td>none</td>
#     </tr>
#     <tr>
#       <td>fluHA_virus_passaged_1</td>
#       <td>db_large</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>none</td>
#       <td>none</td>
#       <td>none</td>
#       <td>500</td>
#       <td>none</td>
#     </tr>
#     <tr>
#       <td>fluHA_virus_passaged_2</td>
#       <td>db_large</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>none</td>
#       <td>none</td>
#       <td>none</td>
#       <td>500</td>
#       <td>none</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-Mike-cc</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>monster</td>
#       <td>Nan95</td>
#       <td>3ug</td>
#       <td>none</td>
#       <td>17782.794</td>
#       <td>140</td>
#       <td>none</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-Mike-OL</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>overlay</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>monster</td>
#       <td>Nan95</td>
#       <td>3ug</td>
#       <td>none</td>
#       <td>56234.133</td>
#       <td>140</td>
#       <td>none</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-pCAWS-cc</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>monster</td>
#       <td>wsn</td>
#       <td>3ug</td>
#       <td>none</td>
#       <td>56234.133</td>
#       <td>140</td>
#       <td>none</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-pCAWS-OL</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>overlay</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>monster</td>
#       <td>wsn</td>
#       <td>3ug</td>
#       <td>none</td>
#       <td>25118.864</td>
#       <td>140</td>
#       <td>none</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-pHW-cc-2ug</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>wsn</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>10000</td>
#       <td>140</td>
#       <td>none</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-pHW-cc-4ug</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>wsn</td>
#       <td>none</td>
#       <td>4ug</td>
#       <td>none</td>
#       <td>5623.413</td>
#       <td>140</td>
#       <td>none</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-pHW-cc-4ug</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>sequential</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>17782.794</td>
#       <td>140</td>
#       <td>none</td>
#     </tr>
#     <tr>
#       <td>WTBC-405-pdm-seq</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>sequential</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>17782.794</td>
#       <td>140</td>
#       <td>none</td>
#     </tr>
#     <tr>
#       <td>WTBC-405-wsn-seq</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>sequential</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>wsn</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>5623.413</td>
#       <td>140</td>
#       <td>none</td>
#     </tr>
#     <tr>
#       <td>WTBC-33-wsn-seq</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>sequential</td>
#       <td>wt</td>
#       <td>wsn</td>
#       <td>wsn</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>5623.413</td>
#       <td>140</td>
#       <td>none</td>
#     </tr>
#     <tr>
#       <td>WTBC-405-pdm-OL</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>overlay</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>2511.886</td>
#       <td>140</td>
#       <td>none</td>
#     </tr>
#     <tr>
#       <td>WTBC-405-wsn-OL</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>overlay</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>wsn</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>43287.613</td>
#       <td>140</td>
#       <td>none</td>
#     </tr>
#     <tr>
#       <td>WTBC-33-wsn-OL</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>overlay</td>
#       <td>wt</td>
#       <td>wsn</td>
#       <td>wsn</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>10000</td>
#       <td>140</td>
#       <td>none</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Calculate virions sequenced
#
# When known, calculate the number of virions that were purified to RNA to prepare the sequencing libraries.

# %%
metadata['uL_sup'] = pd.to_numeric(metadata['uL_sup'], errors='coerce')
metadata['titer_uL'] = pd.to_numeric(metadata['titer_uL'], errors='coerce')
metadata['virions'] = metadata['titer_uL'] * metadata['uL_sup']

pd.set_option('max.colwidth', -1)
display(HTML(metadata.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>sample</th>
#       <th>experiment</th>
#       <th>timepoint</th>
#       <th>cells</th>
#       <th>fluNA</th>
#       <th>fluHA</th>
#       <th>fluInt</th>
#       <th>vRNP</th>
#       <th>dna</th>
#       <th>helper</th>
#       <th>titer_uL</th>
#       <th>uL_sup</th>
#       <th>concentrated</th>
#       <th>virions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>fluHA_virus_transfection_1</td>
#       <td>db_large</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>102ug</td>
#       <td>none</td>
#       <td>48063.809</td>
#       <td>500</td>
#       <td>none</td>
#       <td>24031904.50</td>
#     </tr>
#     <tr>
#       <td>fluHA_virus_transfection_2</td>
#       <td>db_large</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>102ug</td>
#       <td>none</td>
#       <td>48063.809</td>
#       <td>500</td>
#       <td>none</td>
#       <td>24031904.50</td>
#     </tr>
#     <tr>
#       <td>fluHA_virus_passaged_1</td>
#       <td>db_large</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>none</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>500</td>
#       <td>none</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <td>fluHA_virus_passaged_2</td>
#       <td>db_large</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>none</td>
#       <td>none</td>
#       <td>NaN</td>
#       <td>500</td>
#       <td>none</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-Mike-cc</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>monster</td>
#       <td>Nan95</td>
#       <td>3ug</td>
#       <td>none</td>
#       <td>17782.794</td>
#       <td>140</td>
#       <td>none</td>
#       <td>2489591.16</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-Mike-OL</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>overlay</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>monster</td>
#       <td>Nan95</td>
#       <td>3ug</td>
#       <td>none</td>
#       <td>56234.133</td>
#       <td>140</td>
#       <td>none</td>
#       <td>7872778.62</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-pCAWS-cc</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>monster</td>
#       <td>wsn</td>
#       <td>3ug</td>
#       <td>none</td>
#       <td>56234.133</td>
#       <td>140</td>
#       <td>none</td>
#       <td>7872778.62</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-pCAWS-OL</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>overlay</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>monster</td>
#       <td>wsn</td>
#       <td>3ug</td>
#       <td>none</td>
#       <td>25118.864</td>
#       <td>140</td>
#       <td>none</td>
#       <td>3516640.96</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-pHW-cc-2ug</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>wsn</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>10000.000</td>
#       <td>140</td>
#       <td>none</td>
#       <td>1400000.00</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-pHW-cc-4ug</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>wsn</td>
#       <td>none</td>
#       <td>4ug</td>
#       <td>none</td>
#       <td>5623.413</td>
#       <td>140</td>
#       <td>none</td>
#       <td>787277.82</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-pHW-cc-4ug</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>sequential</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>17782.794</td>
#       <td>140</td>
#       <td>none</td>
#       <td>2489591.16</td>
#     </tr>
#     <tr>
#       <td>WTBC-405-pdm-seq</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>sequential</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>17782.794</td>
#       <td>140</td>
#       <td>none</td>
#       <td>2489591.16</td>
#     </tr>
#     <tr>
#       <td>WTBC-405-wsn-seq</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>sequential</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>wsn</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>5623.413</td>
#       <td>140</td>
#       <td>none</td>
#       <td>787277.82</td>
#     </tr>
#     <tr>
#       <td>WTBC-33-wsn-seq</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>sequential</td>
#       <td>wt</td>
#       <td>wsn</td>
#       <td>wsn</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>5623.413</td>
#       <td>140</td>
#       <td>none</td>
#       <td>787277.82</td>
#     </tr>
#     <tr>
#       <td>WTBC-405-pdm-OL</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>overlay</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>2511.886</td>
#       <td>140</td>
#       <td>none</td>
#       <td>351664.04</td>
#     </tr>
#     <tr>
#       <td>WTBC-405-wsn-OL</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>overlay</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>wsn</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>43287.613</td>
#       <td>140</td>
#       <td>none</td>
#       <td>6060265.82</td>
#     </tr>
#     <tr>
#       <td>WTBC-33-wsn-OL</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>overlay</td>
#       <td>wt</td>
#       <td>wsn</td>
#       <td>wsn</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>10000.000</td>
#       <td>140</td>
#       <td>none</td>
#       <td>1400000.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Merge samples and metadata
#
# Keep 'samples' as the master dataframe, to which new data will be appended and from which plots will be generated."

# %%
samples = pd.merge(samples, metadata, how="outer")

display(HTML(samples.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>sample</th>
#       <th>datatype</th>
#       <th>gene</th>
#       <th>datafile</th>
#       <th>experiment</th>
#       <th>timepoint</th>
#       <th>cells</th>
#       <th>fluNA</th>
#       <th>fluHA</th>
#       <th>fluInt</th>
#       <th>vRNP</th>
#       <th>dna</th>
#       <th>helper</th>
#       <th>titer_uL</th>
#       <th>uL_sup</th>
#       <th>concentrated</th>
#       <th>nbarcodes</th>
#       <th>virions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>fluHA_virus_transfection_1</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>/shared/ngs/illumina/bloom_lab/190507_M03100_0428_000000000-CG8CT/Data/Intensities/BaseCalls/bcHA-virus-transfection-sample1_S5_L001_R1_001.fastq.gz</td>
#       <td>db_large</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>102ug</td>
#       <td>none</td>
#       <td>48063.809</td>
#       <td>500.0</td>
#       <td>none</td>
#       <td>939.279310</td>
#       <td>24031904.50</td>
#     </tr>
#     <tr>
#       <td>fluHA_virus_transfection_2</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>/shared/ngs/illumina/bloom_lab/190507_M03100_0428_000000000-CG8CT/Data/Intensities/BaseCalls/bcHA-virus-transfection-sample2_S6_L001_R1_001.fastq.gz</td>
#       <td>db_large</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>102ug</td>
#       <td>none</td>
#       <td>48063.809</td>
#       <td>500.0</td>
#       <td>none</td>
#       <td>939.410859</td>
#       <td>24031904.50</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-Mike-cc</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-monster-Mike-cc_S10_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-monster-Mike-cc_S10_L001_R1_001.fastq.gz</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>monster</td>
#       <td>Nan95</td>
#       <td>3ug</td>
#       <td>none</td>
#       <td>17782.794</td>
#       <td>140.0</td>
#       <td>none</td>
#       <td>595.318253</td>
#       <td>2489591.16</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-Mike-OL</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-monster-Mike-OL_S11_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-monster-Mike-OL_S11_L001_R1_001.fastq.gz</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>overlay</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>monster</td>
#       <td>Nan95</td>
#       <td>3ug</td>
#       <td>none</td>
#       <td>56234.133</td>
#       <td>140.0</td>
#       <td>none</td>
#       <td>769.939226</td>
#       <td>7872778.62</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-pCAWS-cc</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-monster-pCAWS-cc_S12_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-monster-pCAWS-cc_S12_L001_R1_001.fastq.gz</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>monster</td>
#       <td>wsn</td>
#       <td>3ug</td>
#       <td>none</td>
#       <td>56234.133</td>
#       <td>140.0</td>
#       <td>none</td>
#       <td>485.420088</td>
#       <td>7872778.62</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-pCAWS-OL</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-monster-pCAWS-OL_S13_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-monster-pCAWS-OL_S13_L001_R1_001.fastq.gz</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>overlay</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>monster</td>
#       <td>wsn</td>
#       <td>3ug</td>
#       <td>none</td>
#       <td>25118.864</td>
#       <td>140.0</td>
#       <td>none</td>
#       <td>585.990695</td>
#       <td>3516640.96</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-pHW-cc-2ug</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-pHW-cc-2ug_S14_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-pHW-cc-2ug_S14_L001_R1_001.fastq.gz</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>wsn</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>10000.000</td>
#       <td>140.0</td>
#       <td>none</td>
#       <td>603.323831</td>
#       <td>1400000.00</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-pHW-cc-4ug</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-pHW-cc-4ug_S15_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-pHW-cc-4ug_S15_L001_R1_001.fastq.gz</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>wsn</td>
#       <td>none</td>
#       <td>4ug</td>
#       <td>none</td>
#       <td>5623.413</td>
#       <td>140.0</td>
#       <td>none</td>
#       <td>732.674950</td>
#       <td>787277.82</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-pHW-cc-4ug</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-pHW-cc-4ug_S15_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-pHW-cc-4ug_S15_L001_R1_001.fastq.gz</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>sequential</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>17782.794</td>
#       <td>140.0</td>
#       <td>none</td>
#       <td>732.674950</td>
#       <td>2489591.16</td>
#     </tr>
#     <tr>
#       <td>WTBC-405-pdm-seq</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/WTBC-405-pdm-seq_S16_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-WTBC-405-pdm-seq_S16_L001_R1_001.fastq.gz</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>sequential</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>17782.794</td>
#       <td>140.0</td>
#       <td>none</td>
#       <td>595.380237</td>
#       <td>2489591.16</td>
#     </tr>
#     <tr>
#       <td>WTBC-405-wsn-seq</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/WTBC-405-wsn-seq_S17_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-WTBC-405-wsn-seq_S17_L001_R1_001.fastq.gz</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>s

# %% [markdown]
# ## Examine distribution of barcodes
# Next, we want to know how the barcodes are distributed. The goal is to have many different barcodes, all with relatively even distribution.  A big problem would be if a few barcodes make up a large portion of the library.

# %%
counts_per_barcode = dms_tools2.codonvarianttable.getCumulVariantsByCount(
                        barcodes,
                        group_cols='sample')

# %%
p = (ggplot(counts_per_barcode, aes('count', 'nvariants')) +
     geom_step() +
     scale_x_log10() +
     facet_wrap('~sample') +
     theme(figure_size=(5, 5)) +
     ylab('number of barcodes with >= this many counts') +
     xlab('number of counts')
     )

_ = p.draw()

# %% [markdown]
# ### Counts for each rank of barcode
#
# Another way to plot this information is to sort the barcodes by rank, and show how many counts the most abundant barcodes have.

# %%
'''p = ggplot(
  counts %>%
    filter(sample == "2-2_6e5_plasmid") %>%
    group_by(sample),
    aes(x=reorder(barcode, -count, sum), y=count)) +
  geom_point(alpha=0.3) +
  scale_y_log10() +
  facet_wrap(~sample, scales = "free") +
  ylab('counts per barcodes') +
  xlab('barcode rank') +
  theme(axis.text.x=element_blank(),
       axis.ticks.x=element_blank())

_ = p.draw()'''
# Out:
# 'p = ggplot(\n  counts %>%\n    filter(sample == "2-2_6e5_plasmid") %>%\n    group_by(sample),\n    aes(x=reorder(barcode, -count, sum), y=count)) +\n  geom_point(alpha=0.3) +\n  scale_y_log10() +\n  facet_wrap(~sample, scales = "free") +\n  ylab(\'counts per barcodes\') +\n  xlab(\'barcode rank\') +\n  theme(axis.text.x=element_blank(),\n       axis.ticks.x=element_blank())\n\n_ = p.draw()'

# %% [markdown]
# ## Rarefaction curves for barcodes
#
# Ultimately, we are not interested in the total number of barcodes, but in ensuring that the barcodes sampled are unique. To study this, we should look at rarefaction curves.

# %%
rarefy_df = []
for sample in barcodes['sample'].unique():
    rarefy_df.append(dms_tools2.codonvarianttable.rarefyBarcodes(
                        barcodes.query('sample == @sample'))
                     .assign(sample=sample))
rarefy_df = pd.concat(rarefy_df)

# %%
p = (ggplot(rarefy_df, aes('ncounts', 'nbarcodes')) +
     geom_step() +
     facet_wrap('~ sample') +
     theme(figure_size=(5, 5),
           axis_text_x=element_text(angle=90))
     )
_ = p.draw()

# %%
p = (ggplot(rarefy_df, aes('ncounts', 'nbarcodes')) +
     geom_step() +
     facet_wrap('~ sample') +
     theme(figure_size=(8, 8),
           axis_text_x=element_text(angle=90))
     + xlim(0,1250) + ylim(0,1250)
     )
_ = p.draw()
# Out:
# /fh/fast/bloom_j/software/conda/envs/BloomLab_v2/lib/python3.6/site-packages/plotnine/geoms/geom_path.py:74: UserWarning: geom_path: Removed 39525 rows containing missing values.
#   warn(msg.format(n1-n2))

# %% [markdown]
# ### Evaluating the libraries at a target sample
#
# Let's evaluate the library diversity at a target sample size. For now, I have chosen to use 1000. This exmaines how many of the barcodes in the first 1000 are likely to be unqiue.

# %%
nbarcodes_observed = 1000
target_df = rarefy_df.query('ncounts == @nbarcodes_observed')

# %%
target_df
# Out:
#      ncounts   nbarcodes                      sample
# 999  1000     939.279310  fluHA_virus_transfection_1
# 999  1000     939.410859  fluHA_virus_transfection_2
# 999  1000     927.177556  fluHA_virus_passaged_1
# 999  1000     927.395491  fluHA_virus_passaged_2
# 999  1000     595.318253  m-WTBC-monster-Mike-cc
# 999  1000     769.939226  m-WTBC-monster-Mike-OL
# 999  1000     485.420088  m-WTBC-monster-pCAWS-cc
# 999  1000     585.990695  m-WTBC-monster-pCAWS-OL
# 999  1000     603.323831  m-WTBC-pHW-cc-2ug
# 999  1000     732.674950  m-WTBC-pHW-cc-4ug
# 999  1000     595.380237  WTBC-405-pdm-seq
# 999  1000     774.387799  WTBC-405-wsn-seq
# 999  1000     739.029490  WTBC-33-wsn-seq
# 999  1000     856.518687  WTBC-405-pdm-OL
# 999  1000     837.923086  WTBC-405-wsn-OL
# 999  1000     756.175851  WTBC-33-wsn-OL

# %%
samples = pd.merge(samples, target_df, how="outer")

samples = samples.drop(columns=['ncounts'])

display(HTML(samples.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>sample</th>
#       <th>datatype</th>
#       <th>gene</th>
#       <th>datafile</th>
#       <th>experiment</th>
#       <th>timepoint</th>
#       <th>cells</th>
#       <th>fluNA</th>
#       <th>fluHA</th>
#       <th>fluInt</th>
#       <th>vRNP</th>
#       <th>dna</th>
#       <th>helper</th>
#       <th>titer_uL</th>
#       <th>uL_sup</th>
#       <th>concentrated</th>
#       <th>nbarcodes</th>
#       <th>virions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>fluHA_virus_transfection_1</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>/shared/ngs/illumina/bloom_lab/190507_M03100_0428_000000000-CG8CT/Data/Intensities/BaseCalls/bcHA-virus-transfection-sample1_S5_L001_R1_001.fastq.gz</td>
#       <td>db_large</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>102ug</td>
#       <td>none</td>
#       <td>48063.809</td>
#       <td>500.0</td>
#       <td>none</td>
#       <td>939.279310</td>
#       <td>24031904.50</td>
#     </tr>
#     <tr>
#       <td>fluHA_virus_transfection_2</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluHA</td>
#       <td>/shared/ngs/illumina/bloom_lab/190507_M03100_0428_000000000-CG8CT/Data/Intensities/BaseCalls/bcHA-virus-transfection-sample2_S6_L001_R1_001.fastq.gz</td>
#       <td>db_large</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>102ug</td>
#       <td>none</td>
#       <td>48063.809</td>
#       <td>500.0</td>
#       <td>none</td>
#       <td>939.410859</td>
#       <td>24031904.50</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-Mike-cc</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-monster-Mike-cc_S10_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-monster-Mike-cc_S10_L001_R1_001.fastq.gz</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>monster</td>
#       <td>Nan95</td>
#       <td>3ug</td>
#       <td>none</td>
#       <td>17782.794</td>
#       <td>140.0</td>
#       <td>none</td>
#       <td>595.318253</td>
#       <td>2489591.16</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-Mike-OL</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-monster-Mike-OL_S11_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-monster-Mike-OL_S11_L001_R1_001.fastq.gz</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>overlay</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>monster</td>
#       <td>Nan95</td>
#       <td>3ug</td>
#       <td>none</td>
#       <td>56234.133</td>
#       <td>140.0</td>
#       <td>none</td>
#       <td>769.939226</td>
#       <td>7872778.62</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-pCAWS-cc</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-monster-pCAWS-cc_S12_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-monster-pCAWS-cc_S12_L001_R1_001.fastq.gz</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>monster</td>
#       <td>wsn</td>
#       <td>3ug</td>
#       <td>none</td>
#       <td>56234.133</td>
#       <td>140.0</td>
#       <td>none</td>
#       <td>485.420088</td>
#       <td>7872778.62</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-monster-pCAWS-OL</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-monster-pCAWS-OL_S13_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-monster-pCAWS-OL_S13_L001_R1_001.fastq.gz</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>overlay</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>monster</td>
#       <td>wsn</td>
#       <td>3ug</td>
#       <td>none</td>
#       <td>25118.864</td>
#       <td>140.0</td>
#       <td>none</td>
#       <td>585.990695</td>
#       <td>3516640.96</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-pHW-cc-2ug</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-pHW-cc-2ug_S14_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-pHW-cc-2ug_S14_L001_R1_001.fastq.gz</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>wsn</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>10000.000</td>
#       <td>140.0</td>
#       <td>none</td>
#       <td>603.323831</td>
#       <td>1400000.00</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-pHW-cc-4ug</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-pHW-cc-4ug_S15_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-pHW-cc-4ug_S15_L001_R1_001.fastq.gz</td>
#       <td>monster</td>
#       <td>rg</td>
#       <td>coculture</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>wsn</td>
#       <td>none</td>
#       <td>4ug</td>
#       <td>none</td>
#       <td>5623.413</td>
#       <td>140.0</td>
#       <td>none</td>
#       <td>732.674950</td>
#       <td>787277.82</td>
#     </tr>
#     <tr>
#       <td>m-WTBC-pHW-cc-4ug</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/m-WTBC-pHW-cc-4ug_S15_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-m-WTBC-pHW-cc-4ug_S15_L001_R1_001.fastq.gz</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>sequential</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>17782.794</td>
#       <td>140.0</td>
#       <td>none</td>
#       <td>732.674950</td>
#       <td>2489591.16</td>
#     </tr>
#     <tr>
#       <td>WTBC-405-pdm-seq</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/WTBC-405-pdm-seq_S16_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-WTBC-405-pdm-seq_S16_L001_R1_001.fastq.gz</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>sequential</td>
#       <td>wt</td>
#       <td>pdm</td>
#       <td>pdm</td>
#       <td>none</td>
#       <td>2ug</td>
#       <td>none</td>
#       <td>17782.794</td>
#       <td>140.0</td>
#       <td>none</td>
#       <td>595.380237</td>
#       <td>2489591.16</td>
#     </tr>
#     <tr>
#       <td>WTBC-405-wsn-seq</td>
#       <td>viral_barcode_fastqs</td>
#       <td>fluNA</td>
#       <td>/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190306_M04866_0224_000000000-C89KK/Data/Intensities/BaseCalls/WTBC-405-wsn-seq_S17_L001_R1_001.fastq.gz,/fh/fast/bloom_j/SR/ngs/illumina/bloom_lab/190311_M03100_0402_000000000-CC72D/Data/Intensities/BaseCalls/ag-WTBC-405-wsn-seq_S17_L001_R1_001.fastq.gz</td>
#       <td>pilot</td>
#       <td>rg</td>
#       <td>s

# %% [markdown]
# ## Analyze barcodes

# %% [markdown]
# ### Visualize distribution of barcodes

# %%
p = (
    ggplot(samples, aes('sample', 'nbarcodes')) +
    geom_point() +
    ylab('number of unique barcodes') +
    theme(axis_text_x=element_text(angle=90),
          figure_size=(0.6*len(samples['sample'].unique()), 3)) 
    )
_ = p.draw()
# Out:
# /fh/fast/bloom_j/software/conda/envs/BloomLab_v2/lib/python3.6/site-packages/plotnine/layer.py:449: UserWarning: geom_point : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)

# %% [markdown]
# ### Plot diversity as function of titer
#
# Diversity does not seem to correlate with titer, either within an experiment or across it.

# %%
p = (
    ggplot(samples, aes('titer_uL', 'nbarcodes', color = 'experiment')) +
    geom_point() +
    ylab('number of unique barcodes') +
    theme(axis_text_x=element_text(angle=90),
          figure_size=(6, 3)) 
    )
_ = p.draw()
# Out:
# /fh/fast/bloom_j/software/conda/envs/BloomLab_v2/lib/python3.6/site-packages/plotnine/layer.py:449: UserWarning: geom_point : Removed 4 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)

# %% [markdown]
# ### Plot diversity as function of virions loaded for sequencing
# Again, there doesn't seem to be a trend based on how many virions were sampled from the sups for sequencing. We can say, however, that loading a lot more virions did not increase diversity much over loading three orders of magnitude fewer!

# %%
p = (
    ggplot(samples, aes('virions', 'nbarcodes', color = 'experiment')) +
    geom_point() +
    scale_x_continuous(trans='log10',limits=(100000,100000000)) +
    ylab('number of unique barcodes') +
    theme(axis_text_x=element_text(angle=90),
          figure_size=(6, 3)) 
    )
_ = p.draw()
# Out:
# /fh/fast/bloom_j/software/conda/envs/BloomLab_v2/lib/python3.6/site-packages/plotnine/layer.py:449: UserWarning: geom_point : Removed 4 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)

# %% [markdown]
# ### Plot diversity by cell plating strategy

# %%
p = (
    ggplot(samples, aes('cells', 'nbarcodes', color='experiment')) +
    geom_point() +
    ylab('number of unique barcodes') +
    theme(axis_text_x=element_text(angle=90),
          figure_size=(6, 3)) 
    )
_ = p.draw()
# Out:
# /fh/fast/bloom_j/software/conda/envs/BloomLab_v2/lib/python3.6/site-packages/plotnine/layer.py:449: UserWarning: geom_point : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)

# %% [markdown]
# ####
